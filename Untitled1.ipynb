# %% [markdown]
# <a href="https://colab.research.google.com/github/Jangseohee/Tensor/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 

sess=tf.Session()

x_train=[1,2,3]
y_train=[1,2,3]

W =tf.Variable(tf.random_normal([1]),name='weight')
b= tf.Variable(tf.random_normal([1]),name="bias")

hypothesis= x_train*W+b ## node

cost= tf.reduce_mean(tf.square(hypothesis-y_train))
# cost loss function 의 공식을 그대로 옮겨 놓음. 

optimizer= tf.train.GradientDescentOptimizer(learning_rate=0.01)
train=optimizer.minimize(cost)

sess=tf.Session()
# 세션 만들기

sess.run(tf.global_variables_initializer())
# 텐서 플로우에 있는 변수들을 global_variables_initializer()로 반드시 초기화 해줌
for step in range(2001) :  # step을 2000번 거치는데
  sess.run(train)# train을 run 할때 train 은 optimizer .minimize(cost)에대한 식 
  # 을 하고 그 optimizer 는 tf.train ~~~ 의 가장 최소값을 찾고  cost는 linear regression
  #값을 나타내는것이니까 
  if step %20 == 0 : # 20번 돌때 한번씩 검출
    print(step, sess.run(cost),sess.run(W),sess.run(b))
# cost W b 값을 다 볼 수있다.
# Out:
# 0 3.1747801 [0.4734964] [-0.6761476]
# 20 0.046679143 [1.0904115] [-0.38387388]
# 40 0.016675089 [1.1425486] [-0.34102878]
# 60 0.014911361 [1.1412185] [-0.32263985]
# 80 0.013540629 [1.135093] [-0.30725208]
# 100 0.012297784 [1.1287926] [-0.29279083]
# 120 0.0111690415 [1.1227444] [-0.27902868]
# 140 0.010143913 [1.1169765] [-0.26591513]
# 160 0.009212866 [1.1114792] [-0.2534181]
# 180 0.008367277 [1.1062399] [-0.24150844]
# 200 0.007599302 [1.101247] [-0.23015842]
# 220 0.0069017843 [1.0964888] [-0.2193417]
# 240 0.006268321 [1.0919542] [-0.20903347]
# 260 0.0056929886 [1.0876327] [-0.19920968]
# 280 0.005170473 [1.0835145] [-0.18984756]
# 300 0.0046959077 [1.0795895] [-0.18092556]
# 320 0.004264898 [1.075849] [-0.17242272]
# 340 0.0038734444 [1.0722845] [-0.16431946]
# 360 0.003517922 [1.0688872] [-0.15659706]
# 380 0.0031950297 [1.0656499] [-0.14923756]
# 400 0.0029017832 [1.0625646] [-0.142224]
# 420 0.0026354343 [1.0596241] [-0.13553992]
# ...

# %%
import tensorflow as tf
t=[1,2,3,4,5]
tf.reduce_mean(t)

sess=tf.Session()

print(sess.run(tf.reduce_mean(t)))
# Out:
# 3

# %%
import tensorflow as tf

sess=tf.Session()

W= tf.Variable(tf.random_normal([1]),name='weight')
b= tf.Variable(tf.random_normal([1]),name="bias")

X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)
hypothesis=X*W+b

cost=tf.reduce_mean(tf.square(hypothesis-Y))

optimizer= tf.train.GradientDescentOptimizer(learning_rate=0.01)
train=optimizer.minimize(cost)

sess.run(tf.global_variables_initializer())
for step in range(2001) : 
  cost_val, W_val,b_val, _ = sess.run([cost,W,b,train],
                           feed_dict={X:[1,2,3,4,5],Y:[2.1,3.1,4.1,5.1,6.1]})
  if step%20==0 : 
    print(step,cost_val,W_val,b_val)
   
  
  
print(sess.run(hypothesis,feed_dict={X:[5]}))   
print(sess.run(hypothesis,feed_dict={X:[2.5]}))  
#가설에대해 세션을 run 할때 위에 있는 코드대로 넣어준값에대한 일치값을 찾아줌
# Out:
# 0 5.6282096 [1.7924297] [0.17493536]
# 20 0.18094856 [1.277401] [0.10723843]
# 40 0.15792711 [1.2571418] [0.17167576]
# 60 0.13791896 [1.240292] [0.2324698]
# 80 0.12044567 [1.224555] [0.289285]
# 100 0.10518612 [1.2098488] [0.34237942]
# 120 0.091859706 [1.1961055] [0.39199662]
# 140 0.08022184 [1.1832625] [0.4383644]
# 160 0.07005834 [1.1712604] [0.48169544]
# 180 0.06118243 [1.1600444] [0.5221887]
# 200 0.053431045 [1.149563] [0.5600301]
# 220 0.04666173 [1.139768] [0.5953931]
# 240 0.04075005 [1.1306144] [0.62844026]
# 260 0.035587333 [1.1220604] [0.659323]
# 280 0.0310787 [1.1140667] [0.68818325]
# 300 0.027141258 [1.1065964] [0.7151533]
# 320 0.023702689 [1.0996153] [0.74035704]
# 340 0.020699706 [1.0930915] [0.7639105]
# 360 0.018077228 [1.0869948] [0.7859212]
# 380 0.015787 [1.0812974] [0.80649036]
# 400 0.013786894 [1.0759733] [0.8257126]
# 420 0.012040206 [1.0709977] [0.84367573]
# 440 0.010514813 [1.066348] [0.8604626]
# 460 0.009182649 [1.0620029] [0.8761501]
# ...
